# %%
pip install selenium==4.10.0
# Out:
# Requirement already satisfied: selenium==4.10.0 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: trio~=0.17 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from selenium==4.10.0) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from selenium==4.10.0) (2022.9.14)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from selenium==4.10.0) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from selenium==4.10.0) (0.9.2)
# Requirement already satisfied: sortedcontainers in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (1.15.1)
# Requirement already satisfied: sniffio in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (1.2.0)
# Requirement already satisfied: outcome in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (1.2.0)
# Requirement already satisfied: idna in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio~=0.17->selenium==4.10.0) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium==4.10.0) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium==4.10.0) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium==4.10.0) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\gyoungwon jeong\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.10.0) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 
import time 
import datetime

url = "https://twitter.com"

options = Options()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(options=options)

driver.get(url)

driver.implicitly_wait(3) 

# 로그인
login_button = driver.find_element(By.XPATH, "//span[contains(text(), '로그인')]")
login_button.click()

#아이디 비번 입력
with open(r"C:\Users\Gyoungwon Jeong\Desktop\sol_project_4\10. data crawling\twitter password.txt", "r") as twitter_login:
    lines = twitter_login.readlines()
    id = lines[0].strip()
    pw = lines[1].strip()
    
input_id = driver.find_element(By.XPATH, "//input[@name='text']") 
input_id.send_keys(id)
input_id.send_keys(Keys.ENTER)

input_pw = driver.find_element(By.XPATH, "//input[@name='password']")
input_pw.send_keys(pw)
input_pw.send_keys(Keys.ENTER)

# 최신 트렌드 가져오기
trends_for_you = driver.find_element(By.XPATH, "//div[@aria-label='Timeline: Trending now']")

#span_elements = div_element.find_elements(By.XPATH, ".//span[contains(@class, 'css-901oao')]")
trend_for_you = trends_for_you.find_elements(By.XPATH, ".//span[contains(@class, 'css-901oao') and not(contains(text(), 'Trends')) and not(contains(text(), 'posts')) and not(contains(text(), 'Trending')) and not(contains(text(), 'Show'))]")

trends = []

for trend in trend_for_you:
    trends.append(trend.text)

print(trends)

#검색 쿼리문 
search_queries = []

today_date = datetime.datetime.now()
yesterday_date = x - datetime.timedelta(days=1)

start_date = yesterday_date.strftime("%Y-%m-%d")
end_date = today_date.strftime("%Y-%m-%d") 

for trend in trends:
    search_query = trend + ' lang:ko ' + 'until:' + end_date + ' since:' + start_date
    search_queries.append(search_query)

print(search_queries)

input_search = driver.find_element(By.XPATH, "//input[@aria-label='Search query']")
input_search.send_keys(search_queries[0])
input_search.send_keys(Keys.ENTER)

while True:
    current_scroll_height = driver.execute_script("return document.documentElement.scrollHeight")
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3)  # 스크롤링 중간에 잠시 대기
    new_scroll_height = driver.execute_script("return document.documentElement.scrollHeight")
    #print("Current Scroll Height:", current_scroll_height)
    #print("New Scroll Height:", new_scroll_height)
    if new_scroll_height == current_scroll_height:
        break
        
#트윗 수집 칼럼 {닉네임(id), 고유 아이디(username), 작성 날짜(writed_at), 트윗 내용(content), reply 수(reply_count), retweet 수(retweet_count), like 수(like_count), view 수(view_count)}
#일단 트윗 내용만 수집

timeline = driver.find_element(By.XPATH, "//div[@aria-label='Timeline: Search timeline']")
inner_div = timeline.find_element(By.XPATH, "//div[@data-testid='cellInnerDiv']")
tweet_elements = inner_div.find_elements(By.XPATH, "//div[@class='css-901oao r-18jsvk2 r-37j5jr r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-bnwqim r-qvutc0' and @data-testid='tweetText']")

tweet = []
for tweet_element in tweet_elements: 
    tweet.append(tweet_element.text.strip())

print(tweet)
                
# 브라우저 종료
#driver.quit()
# Out:
# ['조슈아 여친', '이미지 실추', '#우린_헤어지지_말자', '#알리지_생일자_에스쿱스_등장중', '태풍 카눈', '쿱스 생일', '잼버리 콘서트', '#rt된_수만큼_n금_그려보자', 'D-100', '본계 들켰을때']
# ['조슈아 여친 lang:ko until:2023-08-09 since:2023-08-07', '이미지 실추 lang:ko until:2023-08-09 since:2023-08-07', '#우린_헤어지지_말자 lang:ko until:2023-08-09 since:2023-08-07', '#알리지_생일자_에스쿱스_등장중 lang:ko until:2023-08-09 since:2023-08-07', '태풍 카눈 lang:ko until:2023-08-09 since:2023-08-07', '쿱스 생일 lang:ko until:2023-08-09 since:2023-08-07', '잼버리 콘서트 lang:ko until:2023-08-09 since:2023-08-07', '#rt된_수만큼_n금_그려보자 lang:ko until:2023-08-09 since:2023-08-07', 'D-100 lang:ko until:2023-08-09 since:2023-08-07', '본계 들켰을때 lang:ko until:2023-08-09 since:2023-08-07']
# ['#조슈아여친 \n지금 난 연애 때문에 이러는 게 아니라 그것 때문에 팬들이랑 소통하는 위버스를 아예 내팽개치고 있었다는 게 너무 짜증 남 아이돌이 연애한다고 욕하던 시기 다 지남 이유는 팬들이랑 소통을 절단했단 거잖아.. 그것 때문에 난 좀 실망함.. 슈아 좋아했던 사람으로서 상처가 많이 컸음', '조슈아 여친 해명글', '시발 순덕년들 아직도 부정중 ㅋㅋㅋㅋㅋㅋ 정신차려요 좀 그럴수록 조슈아랑 조슈아 여친만 이득임 니네는 손해라고 븅신드라... 왜 알지를 못해 조슈아는 잃을게 없어 조슈아 여친도 팔로워 존나 쓸어담았잖아 ㅋㅋ 순덕년들아 제발 그만해 너네 때문에 조슈아가 그 지랄 떤거임 썅 좆같아', '와 #조슈아여친', '드디어 떴다 시발 조슈아 여친 조슈아여친']
